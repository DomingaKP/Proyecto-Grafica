# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/Estadística General Penitenciaria - DATOS AGOSTO 2024 RM.csv')

df.head()
# Out:
#         Fecha               Región        Establecimiento Administracion  \
# 0  31/08/2024  Región Metropolitana    C.A.I.S. Melipilla    Tradicional
# 1  31/08/2024  Región Metropolitana    C.A.I.S. Melipilla    Tradicional
# 2  31/08/2024  Región Metropolitana    C.A.I.S. Melipilla    Tradicional
# 3  31/08/2024  Región Metropolitana    C.A.I.S. Melipilla    Tradicional
# 4  31/08/2024  Región Metropolitana  C.A.I.S. Puente Alto    Tradicional
#
#                      Subsistema                               Régimen  \
# 0            Subsistema Cerrado            Régimen de Control Abierto
# 1            Subsistema Abierto            Régimen de Control Abierto
# 2  Subsistema Postpenitenciario  Régimen de Control Postpenitenciario
# 3  Subsistema Postpenitenciario  Régimen de Control Postpenitenciario
# 4            Subsistema Cerrado            Régimen de Control Abierto
#
#                         Tipo                                Población    Sexo  \
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/Estadística General Penitenciaria - DATOS REGIONES AGOSTO 2024.csv')

df.head()
# Out:
#    31/08/2024  Región de Antofagasta             C.A.I.S. Antofagasta  \
# 0  31/08/2024  Región de Antofagasta             C.A.I.S. Antofagasta
# 1  31/08/2024  Región de Antofagasta  C.C.P. Antofagasta concesionado
# 2  31/08/2024  Región de Antofagasta  C.C.P. Antofagasta concesionado
# 3  31/08/2024  Región de Antofagasta  C.C.P. Antofagasta concesionado
# 4  31/08/2024  Región de Antofagasta  C.C.P. Antofagasta concesionado
#
#     Tradicional            Subsistema Cerrado  \
# 0   Tradicional  Subsistema Postpenitenciario
# 1  Concesionada            Subsistema Cerrado
# 2  Concesionada            Subsistema Cerrado
# 3  Concesionada            Subsistema Cerrado
# 4  Concesionada            Subsistema Cerrado
#
#              Régimen de Control Abierto  Beneficios de Reinserción  \
# 0  Régimen de Control Postpenitenciario          Postpenitenciario
# 1            Régimen de Control Abierto  Beneficios de Reinserción
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/Estadística General Penitenciaria - DATOS REGIONES AGOSTOS 2023.csv')

df.head()
# Out:
#             Tipo de población  Hombres  Mujeres    TOTAL       %
# 0  Total de población vigente  109.804   12.698  122.502  100.00
# 1          Subsistema Cerrado   50.416    4.262   54.678   44.63
# 2  Régimen de control cerrado   47.155    3.917   51.072   41.69
# 3                   Detenidos       58   18.000   76.000    0.06
# 4                  Procesados       13    0.000   13.000    0.01

# %%
import pandas as pd

df = pd.read_csv('/content/Estadística General Penitenciaria - DATOS REGIONES AGOSTOS 2023.csv')

df.head()
# Out:
#             Tipo de población  Hombres  Mujeres    TOTAL       %
# 0  Total de población vigente  109.804   12.698  122.502  100.00
# 1          Subsistema Cerrado   50.416    4.262   54.678   44.63
# 2  Régimen de control cerrado   47.155    3.917   51.072   41.69
# 3                   Detenidos       58   18.000   76.000    0.06
# 4                  Procesados       13    0.000   13.000    0.01
