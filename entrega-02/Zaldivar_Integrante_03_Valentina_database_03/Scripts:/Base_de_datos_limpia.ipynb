# %% [markdown]
# # **Este es mi csv con la base de datos limpia**

# %%
import pandas as pd
df = pd.read_csv('/content/Datos Gráfica - Datos limpios.csv')
df.head()
# Out:
#               Producto   Año Días de flujo Mínimo Mensual Máximo Mensual   \
# 0  Toallas desechables  2021             3    $1.690               $3.299
# 1  Toallas desechables  2022             3         $1.688         $10.103
# 2  Toallas desechables  2023             3           $960          $6.768
# 3  Toallas desechables  2021             5         $2.790          $3.499
# 4  Toallas desechables  2022             5         $2.813         $16.838
#
#   Promedio Mensual  Mínimo Anual Máximo Anual  Promedio Anual
# 0            $2.389      $20.280       $39.588         $28.668
# 1            $3.024      $20.250      $121.230         $36.285
# 2            $3.319      $11.520       $81.216         $39.829
# 3            $3.167      $33.480       $41.988         $38.004
# 4            $5.040      $33.750     $202.050          $60.476
